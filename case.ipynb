# %% [markdown]
# ### Caso - Cancelamento de Clientes
#
#  Recentemente a empresa percebeu que da sua base total de clientes, a maioria são clientes inativos, ou seja, que já cancelaram o serviço.
#
#  Precisando melhorar seus resultados ela quer conseguir entender os principais motivos desses cancelamentos e quais as ações mais eficientes para reduzir esse número.

# %%
# Importação das bibliotecas necessárias
import pandas as pd
import plotly.express as px

# %%
# Leitura do arquivo CSV e exibição das primeiras linhas do DataFrame
df = pd.read_csv('cancelamentos.csv')
df.head(10)
# Out:
#    CustomerID  idade    sexo  tempo_como_cliente  frequencia_uso  \
# 0    349936.0   23.0    Male                13.0            22.0
# 1    100634.0   49.0    Male                55.0            16.0
# 2    301263.0   30.0    Male                 7.0             1.0
# 3    119358.0   26.0    Male                40.0             5.0
# 4    130955.0   27.0  Female                17.0            30.0
# 5    423992.0   30.0     NaN                 NaN            12.0
# 6    345190.0   49.0    Male                 6.0             7.0
# 7    405747.0   33.0    Male                15.0            18.0
# 8    298708.0   19.0  Female                59.0            19.0
# 9    269544.0   27.0  Female                 1.0            13.0
#
#    ligacoes_callcenter  dias_atraso assinatura duracao_contrato  total_gasto  \
# 0                  2.0          1.0   Standard           Annual       909.58
# 1                  3.0          6.0    Premium          Monthly       207.00
# 2                  0.0          8.0      Basic           Annual       768.78
# 3                  3.0          8.0    Premium           Annual       398.00
# 4                  5.0          6.0      Basic           Annual       507.00
# 5                  3.0          7.0   Standard        Quarterly       641.78
# 6                  0.0          0.0   Standard           Annual       751.00
# 7                  1.0         20.0   Standard           Annual       839.71
# 8                  1.0          4.0      Basic        Quarterly       543.93
# 9                  0.0         11.0    Premium           Annual       621.67
#
#    meses_ultima_interacao  cancelou
# 0                    23.0       0.0
# 1                    29.0       1.0
# 2                     7.0       0.0
# 3                    12.0       1.0
# 4                    15.0       1.0
# 5                     7.0       0.0
# 6                    11.0       0.0
# 7                    25.0       0.0
# 8                     7.0       0.0
# 9                     6.0       0.0
